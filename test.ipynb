# %%
import matplotlib.image as img
import matplotlib.pyplot as plt

img = img.imread('pic1.png')
print(img)
# Out:
# [[[0.53333336 0.         0.08235294]
#   [0.53333336 0.         0.08235294]
#   [0.53333336 0.         0.08235294]
#   ...
#   [0.53333336 0.         0.08235294]
#   [0.53333336 0.         0.08235294]
#   [0.53333336 0.         0.08235294]]
#
#  [[0.53333336 0.         0.08235294]
#   [0.53333336 0.         0.08235294]
#   [0.53333336 0.         0.08235294]
#   ...
#   [0.53333336 0.         0.08235294]
#   [0.53333336 0.         0.08235294]
#   [0.53333336 0.         0.08235294]]
#
#  [[0.53333336 0.         0.08235294]
#   [0.53333336 0.         0.08235294]
#   [0.53333336 0.         0.08235294]
#   ...
#   [0.53333336 0.         0.08235294]
#   [0.53333336 0.         0.08235294]
#   [0.53333336 0.         0.08235294]]
#
#  ...
#
#  [[0.53333336 0.         0.08235294]
#   [0.53333336 0.         0.08235294]
#   [0.53333336 0.         0.08235294]
#   ...
#   [0.53333336 0.         0.08235294]
#   [0.53333336 0.         0.08235294]
#   [0.53333336 0.         0.08235294]]
#
# ...
